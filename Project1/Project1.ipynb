# %%
import pandas as pd
import seaborn as sns
dataset = pd.read_csv("TSLA.csv")
dataset = dataset.drop("Open", axis=1)
dataset = dataset.drop("Close", axis=1)
dataset = dataset.drop("Adj Close", axis=1)
row_with_null = is_null.any(axis=1)
rows_with_null = dataset[row_with_null]
dataset["High"]=pd.to_numeric(dataset["High"])#1
dataset["Low"]=pd.to_numeric(dataset["Low"])#2
dataset["Volume"]=pd.to_numeric(dataset["Volume"])#3
dataset = dataset.assign(Average=(dataset['High'] + dataset['Low']) / 2)
dataset = dataset.sort_values(by='Date', ascending=True)
dataset_new = dataset[["Date", "High", "Low", "Average", "Volume"]]
dataset_new.to_csv("TSLA_NEW.csv")
print(dataset_new)
data_visualisation2 = sns.barplot(data=dataset, x="Date", y="Average")
print(data_visualisation2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\585023058.py in <module>
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 dataset = pd.read_csv("TSLA.csv")
#       4 dataset = dataset.drop("Open", axis=1)
#       5 dataset = dataset.drop("Close", axis=1)
#
# D:\ANACONDA\lib\site-packages\seaborn\__init__.py in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#       5 from .relational import *  # noqa: F401,F403
#
# D:\ANACONDA\lib\site-packages\seaborn\rcmod.py in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#       8
#       9
#
# D:\ANACONDA\lib\site-packages\seaborn\palettes.py in <module>
# ...
